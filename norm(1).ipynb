# %%
import pandas as pd
import numpy as np

# Загрузка данных
df = pd.read_excel('Data_Asya.xlsx')

features = [
    ('Date_Portfolio_USD', 'Portfolio_USD'),
    ('Date_Natural Gas EU Dutch TTF (EUR/Wh)', 'Natural Gas EU Dutch TTF (EUR/Wh)'),
    # ('Date_U.S.Crude Oil Inventories', 'U.S.Crude Oil Inventories'),
    ('Date_United States Fed Funds Interest Rate', 'United States Fed Funds Interest Rate'),
    ('Date_Brent Oil Futures - Jun 25 (LCO5)', 'Brent Oil Futures - Jun 25 (LCO5)')
]

result_df = pd.DataFrame()

for date_col, value_col in features:
    # Создаем временный DataFrame для каждого признака
    temp_df = df[[date_col, value_col]].copy()

    # Преобразуем даты и значения
    temp_df[date_col] = pd.to_datetime(temp_df[date_col], format='%d.%m.%Y', errors='coerce').dt.normalize()  # Убираем время
    temp_df[value_col] = pd.to_numeric(temp_df[value_col], errors='coerce')

    # Удаляем строки с невалидными датами и дубликаты
    temp_df = temp_df.dropna(subset=[date_col])
    temp_df = temp_df.drop_duplicates(subset=[date_col], keep='last')

    # Переименовываем столбец с датой для унификации
    temp_df = temp_df.rename(columns={date_col: 'Date'})

    # Объединяем данные
    if result_df.empty:
        result_df = temp_df
    else:
        result_df = pd.merge(result_df, temp_df, on='Date', how='outer')

# Сортируем по дате и сбрасываем индекс
result_df = result_df.sort_values('Date').reset_index(drop=True)

# Выводим статистику ДО преобразования даты в строку
# print("Статистика числовых столбцов:")
# print(result_df.describe())
# print(result_df)

# Форматируем даты для Excel
# result_df['Date'] = result_df['Date'].dt.strftime('%Y-%m-%d')

# Сохраняем в Excel
# result_df.to_excel('result_data.xlsx', index=False)

result_df['Date'] = pd.to_datetime(result_df['Date'])
result_df = result_df.set_index('Date')
# Приводим индекс к формату datetime
result_df.index = pd.to_datetime(result_df.index)

# Создаем полный диапазон дат
full_index = pd.date_range(start=result_df.index.min(), end=result_df.index.max(), freq='D')
result_df = result_df.reindex(full_index)

print("Количество пропусков до интерполяции:")
print(result_df.isnull().sum())
print(result_df.dtypes)
print(result_df.head())
print(result_df.describe)
# Out:
# Количество пропусков до интерполяции:
# Portfolio_USD                            1533
# Natural Gas EU Dutch TTF (EUR/Wh)        1414
# United States Fed Funds Interest Rate    4238
# Brent Oil Futures - Jun 25 (LCO5)        1283
# dtype: int64
# Portfolio_USD                            float64
# Natural Gas EU Dutch TTF (EUR/Wh)        float64
# United States Fed Funds Interest Rate    float64
# Brent Oil Futures - Jun 25 (LCO5)        float64
# dtype: object
#             Portfolio_USD  Natural Gas EU Dutch TTF (EUR/Wh)  \
# 2013-01-02     988.839122                                NaN
# 2013-01-03     997.739901                                NaN
# 2013-01-04    1016.371927                               27.2
# 2013-01-05            NaN                                NaN
# 2013-01-06            NaN                                NaN
#
#             United States Fed Funds Interest Rate  \
# 2013-01-02                                    NaN
# 2013-01-03                                    NaN
# 2013-01-04                                    NaN
# 2013-01-05                                    NaN
# 2013-01-06                                    NaN
#
#             Brent Oil Futures - Jun 25 (LCO5)
# 2013-01-02                             112.47
# 2013-01-03                             112.14
# 2013-01-04                             111.31
# 2013-01-05                                NaN
# 2013-01-06                                NaN
# <bound method NDFrame.describe of             Portfolio_USD  Natural Gas EU Dutch TTF (EUR/Wh)  \
# 2013-01-02     988.839122                                NaN
# 2013-01-03     997.739901                                NaN
# 2013-01-04    1016.371927                            27.2000
# 2013-01-05            NaN                                NaN
# 2013-01-06            NaN                                NaN
# ...                   ...                                ...
# 2024-12-27     822.136969                            47.7804
# 2024-12-28            NaN                                NaN
# 2024-12-29            NaN                                NaN
# 2024-12-30     820.719522                            48.1853
# 2024-12-31     831.305501                            50.4541
#
#             United States Fed Funds Interest Rate  \
# 2013-01-02                                    NaN
# 2013-01-03                                    NaN
# 2013-01-04                                    NaN
# 2013-01-05                                    NaN
# 2013-01-06                                    NaN
# ...                                           ...
# 2024-12-27                                    NaN
# 2024-12-28                                    NaN
# 2024-12-29                                    NaN
# 2024-12-30                                    NaN
# 2024-12-31                                    NaN
#
#             Brent Oil Futures - Jun 25 (LCO5)
# 2013-01-02                             112.47
# 2013-01-03                             112.14
# 2013-01-04                             111.31
# 2013-01-05                                NaN
# 2013-01-06                                NaN
# ...                                       ...
# 2024-12-27                              74.17
# 2024-12-28                                NaN
# 2024-12-29                                NaN
# 2024-12-30                              74.39
# 2024-12-31                              74.64
#
# [4382 rows x 4 columns]>

# %%
target_col = 'Portfolio_USD'
feature_cols = ['Portfolio_USD',
                'Natural Gas EU Dutch TTF (EUR/Wh)',
                # 'U.S.Crude Oil Inventories',
                'United States Fed Funds Interest Rate',
                'Brent Oil Futures - Jun 25 (LCO5)']
df = result_df[feature_cols].copy()

# %% [raw]
# 1. Что такое lookback (окно истории)?
#
#     Это количество дней, которые модель будет «смотреть назад», чтобы сделать прогноз.
#     Пример: Если lookback = 30, модель для предсказания завтрашнего дня использует данные последних 30 дней.
#
# 2. Как делить данные, чтобы всё работало?
#
# Допустим, хотим:
#
#     Прогнозировать на 14 дней (горизонт прогноза = 14).
#
#     Использовать историю 30 дней (lookback = 30).
#
# Наши данные:
#
#     Всего 4383 дня (2013-01-02 — 2024-12-31).
#
#     Тестовая выборка должна содержать минимум 14 дней (горизонт) + 30 дней (lookback) = 44 дня.
#
# Шаги:
#
#     Выделить тест: Последние 44 дня (например, 2024-11-18 — 2024-12-31).
#
#     Трейн: Все данные до 2024-11-17.
#
# Проверка:
#
#     Для прогноза на 2024-12-01 модель должна использовать данные с 2024-11-01 по 2024-11-30 (lookback=30).
#
#     Если тест короче 44 дней — будет ошибка при создании окон
#
# Конкретный пример для наших данных
#
# Допустим:
#
#     Lookback = 30 дней,
#
#     Горизонт прогноза = 14 дней.
#
# Разделение:
#
#     Тест: Последние 44 дня (14 дней прогноза + 30 дней для истории).
#
#     Трейн: Все данные до начала теста.
#
# Как это выглядит в датах:
#
#     Конец трейна: 2024-11-17,
#
#     Начало теста: 2024-11-18,
#
#     Прогнозируемые дни: 2024-12-01 — 2024-12-14 (14 дней).

# %%
# параметры
lookback = 30  # история
horizon = 14   # прогноз

# Размер теста = lookback + horizon
test_size = lookback + horizon

# Разделение данных
train = df.iloc[:-test_size]
test = df.iloc[-test_size:]

# Проверка дат
print("Начало теста:", test.index[0])  # Должно быть 2024-11-18
print("Прогнозируемый период:", test.index[-horizon:])  # 2024-12-01 — 2024-12-14
# Out:
# Начало теста: 2024-11-18 00:00:00
# Прогнозируемый период: DatetimeIndex(['2024-12-18', '2024-12-19', '2024-12-20', '2024-12-21',
#                '2024-12-22', '2024-12-23', '2024-12-24', '2024-12-25',
#                '2024-12-26', '2024-12-27', '2024-12-28', '2024-12-29',
#                '2024-12-30', '2024-12-31'],
#               dtype='datetime64[ns]', freq='D')

# %% [raw]
# Импьютация в трейне
# Для каждого признака используем методы, не требующие будущих данных:

# %%
# Заполняем пропуски в трейне
train_imputed = train.copy()

# Для каждого признака свой метод
train_imputed['Portfolio_USD'] = train['Portfolio_USD'].interpolate(method='time').bfill()
train_imputed['Natural Gas EU Dutch TTF (EUR/Wh)'] = train['Natural Gas EU Dutch TTF (EUR/Wh)'].ffill()
# train_imputed['U.S.Crude Oil Inventories'] = train['U.S.Crude Oil Inventories'].fillna(train['U.S.Crude Oil Inventories'].median())  # еженедельные данные
train_imputed['United States Fed Funds Interest Rate'] = train['United States Fed Funds Interest Rate'].ffill()  # процентная ставка редко меняется
train_imputed['Brent Oil Futures - Jun 25 (LCO5)'] = train['Brent Oil Futures - Jun 25 (LCO5)'].interpolate(method='linear')
print("Количество пропусков в трейне после импьютации:")
print(train_imputed.isnull().sum())
# Out:
# Количество пропусков в трейне после импьютации:
# Portfolio_USD                             0
# Natural Gas EU Dutch TTF (EUR/Wh)         2
# United States Fed Funds Interest Rate    28
# Brent Oil Futures - Jun 25 (LCO5)         0
# dtype: int64

# %% [raw]
# Почему остались пропуски?
#
#     Оставшиеся пропуски в train_imputed говорят о том, что методы заполнения (интерполяция, ffill/bfill) не смогли обработать крайние случаи.
#
# Возможные причины:
#
#     Пропуски в начале трейна (нечего заполнять через ffill).
#
#     Длинные последовательности пропусков (например, 30 дней подряд).
#
#     Признаки, которые нельзя интерполировать (например, процентная ставка ФРС меняется скачкообразно).
#
# Найдем даты с пропусками:

# %%
# Для Natural Gas EU Dutch TTF
nan_gas = train_imputed[train_imputed["Natural Gas EU Dutch TTF (EUR/Wh)"].isna()]
print("Даты с пропусками в Natural Gas:\n", nan_gas.index)

# Для United States Fed Funds Interest Rate
nan_interest = train_imputed[train_imputed["United States Fed Funds Interest Rate"].isna()]
print("\nДаты с пропусками в Interest Rate:\n", nan_interest.index)
# Out:
# Даты с пропусками в Natural Gas:
#  DatetimeIndex(['2013-01-02', '2013-01-03'], dtype='datetime64[ns]', freq='D')
#
# Даты с пропусками в Interest Rate:
#  DatetimeIndex(['2013-01-02', '2013-01-03', '2013-01-04', '2013-01-05',
#                '2013-01-06', '2013-01-07', '2013-01-08', '2013-01-09',
#                '2013-01-10', '2013-01-11', '2013-01-12', '2013-01-13',
#                '2013-01-14', '2013-01-15', '2013-01-16', '2013-01-17',
#                '2013-01-18', '2013-01-19', '2013-01-20', '2013-01-21',
#                '2013-01-22', '2013-01-23', '2013-01-24', '2013-01-25',
#                '2013-01-26', '2013-01-27', '2013-01-28', '2013-01-29'],
#               dtype='datetime64[ns]', freq='D')

# %% [raw]
# 1. Natural Gas EU Dutch TTF (EUR/Wh):
#     Пропуски: 2 дня (2013-01-02, 2013-01-03).
#
# Причина:
#     Данные начинаются с 2013-01-04 (значение 27.2). Вероятно, сбор данных стартовал позже или это выходные/праздники.
#
# Решение:
#     Заполнить пропуски первым доступным значением (2013-01-04) через backward fill (bfill)

# %%
train_imputed["Natural Gas EU Dutch TTF (EUR/Wh)"] = train_imputed["Natural Gas EU Dutch TTF (EUR/Wh)"].bfill()
# перепроверяем
nan_gas = train_imputed[train_imputed["Natural Gas EU Dutch TTF (EUR/Wh)"].isna()]
print("Даты с пропусками в Natural Gas:\n", nan_gas.index)
# Out:
# Даты с пропусками в Natural Gas:
#  DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %% [raw]
# 2. United States Fed Funds Interest Rate:
#     Пропуски: 28 дней подряд (2013-01-02 — 2013-01-29).
#
# Причина:
#     Процентная ставка ФРС не публикуется ежедневно. Она меняется только после решений ФРС (примерно 8 раз в год). В нашем случае данные начинаются
#     позже.
#
# Решение:
#     Если в трейне есть хотя бы одно ненулевое значение ставки после 2013-01-29:
#     Заполним пропуски последним известным значением через backward fill (предполагаем, что ставка не менялась до первого объявления)

# %%
train_imputed["United States Fed Funds Interest Rate"] = train_imputed["United States Fed Funds Interest Rate"].bfill()
# проверяем
nan_interest = train_imputed[train_imputed["United States Fed Funds Interest Rate"].isna()]
print("\nДаты с пропусками в Interest Rate:\n", nan_interest.index)
# Out:
# Даты с пропусками в Interest Rate:
#  DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %% [raw]
# Перепроверим пропуски в тесте

# %%
print("Количество пропусков в трейне после импьютации:")
print(train_imputed.isnull().sum())
# Out:
# Количество пропусков в трейне после импьютации:
# Portfolio_USD                            0
# Natural Gas EU Dutch TTF (EUR/Wh)        0
# United States Fed Funds Interest Rate    0
# Brent Oil Futures - Jun 25 (LCO5)        0
# dtype: int64

# %% [raw]
# Пропусков в тесте больше нет.
#
# Приступим к импьютации в тест.
#     Используем статистики (медиану, среднее) только из трейна

# %%
# Импортируем SimpleImputer
from sklearn.impute import SimpleImputer

# Создаем импьютер, обучаем на трейне
imputer = SimpleImputer(strategy='median')
imputer.fit(train_imputed)  # обучаем НА УЖЕ ЗАПОЛНЕННОМ ТРЕЙНЕ!

# Заполняем тест
test_imputed = test.copy()
test_imputed = pd.DataFrame(imputer.transform(test_imputed), columns=test.columns, index=test.index)
print("Количество пропусков в тесте после импьютации:")
print(test_imputed.isnull().sum())
# Out:
# Количество пропусков в тесте после импьютации:
# Portfolio_USD                            0
# Natural Gas EU Dutch TTF (EUR/Wh)        0
# United States Fed Funds Interest Rate    0
# Brent Oil Futures - Jun 25 (LCO5)        0
# dtype: int64

# %% [raw]
# Теперь данные необходимо нормализовать (до диапазона -1;1, именно для LSTM). Для нормализации будем использовать MinMaxScaler.
# Этот скейлер требует распределения близкого к нормальному.
# Проанализируем распределения фичей и выбросы в них.

# %%
# from dataprep.eda import create_report
# report = create_report(train_imputed)
# create_report(train_imputed).show_browser()
# report.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Список признаков
features = train_imputed.columns

# Гистограммы
plt.figure(figsize=(15, 10))
for i, feature in enumerate(features, 1):
    plt.subplot(2, 3, i)
    sns.histplot(train_imputed[feature], kde=True)
    plt.title(f'Распределение {feature}')
plt.tight_layout()
plt.show()

for column_name in train_imputed.columns:
    # Ящики с усами
    plt.figure(figsize=(15, 6))
    sns.boxplot(data=train_imputed[column_name])
    plt.xticks(rotation=45)
    plt.title("Выбросы")
    plt.show()

# %%
import pandas as pd

# Описательные статистики
stats = train_imputed.describe(percentiles=[0.05, 0.25, 0.5, 0.75, 0.95]).transpose()
stats["IQR"] = stats["75%"] - stats["25%"]

# Считаем границы выбросов и количество
outliers_info = []
for col in train_imputed.columns:
    q1 = stats.loc[col, "25%"]
    q3 = stats.loc[col, "75%"]
    iqr = stats.loc[col, "IQR"]
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    mask_low = (train_imputed[col] < lower_bound)
    mask_high = (train_imputed[col] > upper_bound)

    outliers_info.append({
        "Признак": col,
        "Выбросы_низ": mask_low.sum(),
        "Выбросы_верх": mask_high.sum(),
        "Всего_выбросов": mask_low.sum() + mask_high.sum(),
        "LowerBound": lower_bound,
        "UpperBound": upper_bound
    })

# Создаем DataFrame с информацией о выбросах
outliers_df = pd.DataFrame(outliers_info).set_index("Признак")

# Объединяем со статистиками
stats = stats.merge(
    outliers_df[["Выбросы_низ", "Выбросы_верх", "Всего_выбросов", "LowerBound", "UpperBound"]],
    left_index=True,
    right_index=True
)

# Выводим результат
stats[["mean", "std", "min", "5%", "50%", "95%", "max", "IQR",
       "Выбросы_низ", "Выбросы_верх", "Всего_выбросов", "LowerBound", "UpperBound"]]
# Out:
#                                              mean         std        min  \
# Portfolio_USD                          888.514810  157.993992  391.34414
# Natural Gas EU Dutch TTF (EUR/Wh)       33.268799   36.737169    3.50900
# United States Fed Funds Interest Rate    1.614338    1.808238    0.25000
# Brent Oil Futures - Jun 25 (LCO5)       72.698336   22.554171   19.33000
#
#                                                5%         50%          95%  \
# Portfolio_USD                          569.488224  924.738692  1113.224086
# Natural Gas EU Dutch TTF (EUR/Wh)        9.964000   21.622500   109.800900
# United States Fed Funds Interest Rate    0.250000    0.500000     5.500000
# Brent Oil Futures - Jun 25 (LCO5)       40.304000   71.115000   110.754667
#
#                                                max         IQR  Выбросы_низ  \
# Portfolio_USD                          1241.052795  175.705652          159
# Natural Gas EU Dutch TTF (EUR/Wh)       339.196000   14.547325            0
# United States Fed Funds Interest Rate     5.500000    2.000000            0
# Brent Oil Futures - Jun 25 (LCO5)       127.980000   31.136667            0
#
#                                        Выбросы_верх  Всего_выбросов  \
# Portfolio_USD                                     0             159
# Natural Gas EU Dutch TTF (EUR/Wh)               532             532
# United States Fed Funds Interest Rate           420             420
# Brent Oil Futures - Jun 25 (LCO5)                 0               0
#
#                                        LowerBound   UpperBound
# Portfolio_USD                          554.325829  1257.148438
# Natural Gas EU Dutch TTF (EUR/Wh)       -5.744237    52.445062
# United States Fed Funds Interest Rate   -2.750000     5.250000
# Brent Oil Futures - Jun 25 (LCO5)        8.405833   132.952500

# %% [raw]
# 1. Portfolio_USD
# Проблема: 159 нижних выбросов (значения ниже 554.33), что сжимает основной диапазон данных.
#
# 2. Natural Gas EU Dutch TTF (EUR/Wh)
# Проблема: 532 верхних выброса (значения выше 52.45), сильная асимметрия.
#
# 3. U.S.Crude Oil Inventories
# Проблема: IQR=0 (все данные сосредоточены в одной точке?), 618 выбросов.
#
# Решение:
#
# Считаю, что это в целом лишняя непоказательная фича, дроп.
#
# Если это ошибка измерения или шум:
#
#
# # Замена выбросов медианой
# median_value = train_imputed["U.S.Crude Oil Inventories"].median()
# train_imputed["U.S.Crude Oil Inventories"] = train_imputed["U.S.Crude Oil Inventories"].clip(
#     lower=stats.loc["U.S.Crude Oil Inventories", "5%"],
#     upper=stats.loc["U.S.Crude Oil Inventories", "95%"]
# )
#
# 4. United States Fed Funds Interest Rate
# Проблема: Дискретные изменения ставки, 420 верхних выбросов (реальные события).
#
# Решение: Оставить как есть (выбросы — часть данных).
#
# 5. Brent Oil Futures - Jun 25 (LCO5)
# Проблема: Нет выбросов, равномерное распределение.
#
# Решение: Без обработки.

# %%
lower_bound = 554.33
train_imputed["Portfolio_USD"] = train_imputed["Portfolio_USD"].clip(lower=lower_bound)
upper_bound = 109.8  # 95% перцентиль из таблицы выше
train_imputed["Natural Gas EU Dutch TTF (EUR/Wh)"] = train_imputed["Natural Gas EU Dutch TTF (EUR/Wh)"].clip(upper=upper_bound)
# Логарифмирование для уменьшения skewness
train_imputed["Natural Gas EU Dutch TTF (EUR/Wh)"] = np.log1p(train_imputed["Natural Gas EU Dutch TTF (EUR/Wh)"])

# train_imputed = train_imputed.drop(['U.S.Crude Oil Inventories'], axis=1, inplace=True)
# test_imputed = test_imputed.drop(['U.S.Crude Oil Inventories'], axis=1, inplace=True)

# %%
# Список признаков
features = train_imputed.columns

# Гистограммы
plt.figure(figsize=(15, 10))
for i, feature in enumerate(features, 1):
    plt.subplot(2, 3, i)
    sns.histplot(train_imputed[feature], kde=True)
    plt.title(f'Распределение {feature}')
plt.tight_layout()
plt.show()

for column_name in train_imputed.columns:
    # Ящики с усами
    plt.figure(figsize=(15, 6))
    sns.boxplot(data=train_imputed[column_name])
    plt.xticks(rotation=45)
    plt.title("Выбросы")
    plt.show()

# %% [raw]
# Нормализация

# %%
from sklearn.preprocessing import MinMaxScaler

# Инициализация одного скейлера для всех признаков
scaler = MinMaxScaler(feature_range=(-1, 1))

# Обучение на трейне и преобразование данных
train_scaled = scaler.fit_transform(train_imputed)
test_scaled = scaler.transform(test_imputed)

# %% [raw]
# Создание последовательностей

# %%
def create_sequences(data: np.ndarray,
                     lookback: int,
                     horizon: int,
                     target_col: int = 0):
    """
    data: np.ndarray, shape (n_samples, n_features)
    lookback: int, число временных шагов во входе
    horizon: int, число временных шагов в выходе
    target_col: int, индекс столбца-цели
    """
    X, y = [], []
    for i in range(len(data) - lookback - horizon + 1):
        # окно истории
        seq_x = data[i : i + lookback, :]
        # multistep-цель
        seq_y = data[i + lookback : i + lookback + horizon, target_col]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

X_train, y_train = create_sequences(train_scaled, lookback=30, horizon=14, target_col=0)
X_test,  y_test  = create_sequences(test_scaled,  lookback=30, horizon=14, target_col=0)

# %% [raw]
# Создаём нейронку

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense

# model = Sequential([
#     LSTM(64, input_shape=(30, 4)),
#     Dense(14)
# ])
# model.compile(optimizer='adam', loss='mse')

# %% [raw]
# Ниже кратко по сути: выходной слой Dense(14) делает ровно 14 прогнозов — по одному на каждый из следующих 14 дней. Число “14” взято из horizon, то есть из желаемой длины мультишагового прогноза.
#
# Почему выходной слой имеет 14 нейронов
# В LSTM для multi-step forecasting плотный (Dense) слой формирует вектор предсказаний размером, равным числу шагов вперёд. Каждый нейрон выдаёт прогноз на следующий временной шаг в горизонте
#
# Поскольку мы хотим предсказывать 14 дней подряд, нам нужно 14 выходных величин — соответственно, Dense(14)
#
# Откуда берётся число 14
# Это значение параметра horizon = 14, который мы задали при разделении и в функции create_sequences. Он определяет, сколько точек во “времени” мы прогнозируем после каждого обучающего окна
#
# Если бы вы захотели, скажем, 7-дневный прогноз, слой был бы Dense(7); для 30-дневного — Dense(30) и т. д.
#
# Итого: число нейронов в последнем Dense-слое всегда равно числу шагов в нашем горизонте прогноза. Мы задаём это число сами, исходя из задачи (в нашем случае 14-дневный прогноз).

# %%
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(
    n_splits=5,
    max_train_size=None,  # можно ограничить размер тренировочной части
    test_size=14,         # фиксированный размер валидации
    gap=0                 # пропуск между train и test, уберегает от утечки
)

for fold, (train_idx, val_idx) in enumerate(tscv.split(X_train)):
    print(f"Fold {fold+1}: Train {train_idx[0]}–{train_idx[-1]}, "
          f"Val {val_idx[0]}–{val_idx[-1]}")
    X_tr, y_tr = X_train[train_idx], y_train[train_idx]
    X_va, y_va = X_train[val_idx],   y_train[val_idx]
# Out:
# Fold 1: Train 0–4224, Val 4225–4238
# Fold 2: Train 0–4238, Val 4239–4252
# Fold 3: Train 0–4252, Val 4253–4266
# Fold 4: Train 0–4266, Val 4267–4280
# Fold 5: Train 0–4280, Val 4281–4294

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Списки для логов и лучших значений
val_losses = []
best_val_loss = float('inf')
best_weights = None

# Колбэк для ранней остановки и восстановления лучших весов внутри каждого фолда
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# Цикл кросс-валидации
for fold, (train_idx, val_idx) in enumerate(tscv.split(X_train), start=1):
    # Разбиение на тренировочную и валидационную части
    X_tr, y_tr = X_train[train_idx], y_train[train_idx]
    X_val, y_val = X_train[val_idx],   y_train[val_idx]

    # Создание и компиляция модели с Input слоем вместо input_shape
    model = Sequential([
        Input(shape=(X_tr.shape[1], X_tr.shape[2])),
        LSTM(
            64,
            dropout=0.3,
            recurrent_dropout=0.3
        ),
        Dense(14)
    ])
    model.compile(optimizer='adam', loss='mse')

    # Тренировка с ранней остановкой
    history = model.fit(
        X_tr, y_tr,
        epochs=20,
        batch_size=32,
        validation_data=(X_val, y_val),
        callbacks=[early_stop],
        verbose=1
    )

    # Минимальный val_loss в этом фолде
    fold_best = min(history.history['val_loss'])
    val_losses.append(fold_best)
    print(f"Fold {fold} best val_loss: {fold_best:.4f}")

    # Сохраняем веса, если это новый глобальный минимум
    if fold_best < best_val_loss:
        best_val_loss = fold_best
        best_weights = model.get_weights()

# После кросс-валидации: создаём чистую модель и загружаем в неё лучшие веса
best_model = Sequential([
    Input(shape=(X_train.shape[1], X_train.shape[2])),
    LSTM(
        64,
        dropout=0.3,
        recurrent_dropout=0.3
    ),
    Dense(14)
])
best_model.compile(optimizer='adam', loss='mse')
best_model.set_weights(best_weights)

# Вывод итогового результата
print(f"\nOverall best val_loss: {best_val_loss:.4f}")

# Теперь best_model готова к предсказаниям и дальнейшему использованию
# Out:
# Epoch 1/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - loss: 0.1141 - val_loss: 0.0268
# Epoch 2/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 20s 78ms/step - loss: 0.0494 - val_loss: 0.0278
# Epoch 3/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - loss: 0.0324 - val_loss: 0.0340
# Epoch 4/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - loss: 0.0250 - val_loss: 0.0334
# Epoch 5/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - loss: 0.0230 - val_loss: 0.0196
# Epoch 6/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - loss: 0.0213 - val_loss: 0.0200
# Epoch 7/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 20s 77ms/step - loss: 0.0196 - val_loss: 0.0198
# Epoch 8/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - loss: 0.0192 - val_loss: 0.0264
# Epoch 9/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 20s 75ms/step - loss: 0.0169 - val_loss: 0.0278
# Epoch 10/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - loss: 0.0177 - val_loss: 0.0265
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 5.
# Fold 1 best val_loss: 0.0196
# Epoch 1/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 14s 78ms/step - loss: 0.1164 - val_loss: 0.0070
# Epoch 2/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - loss: 0.0491 - val_loss: 0.0180
# Epoch 3/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0345 - val_loss: 0.0162
# Epoch 4/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0271 - val_loss: 0.0114
# Epoch 5/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0227 - val_loss: 0.0100
# Epoch 6/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0210 - val_loss: 0.0047
# Epoch 7/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 21s 79ms/step - loss: 0.0207 - val_loss: 0.0058
# Epoch 8/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - loss: 0.0187 - val_loss: 0.0092
# Epoch 9/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - loss: 0.0194 - val_loss: 0.0055
# Epoch 10/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0155 - val_loss: 0.0109
# Epoch 11/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - loss: 0.0162 - val_loss: 0.0075
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
# Fold 2 best val_loss: 0.0047
# Epoch 1/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 14s 82ms/step - loss: 0.1040 - val_loss: 0.0063
# Epoch 2/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - loss: 0.0485 - val_loss: 0.0090
# Epoch 3/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 0.0331 - val_loss: 0.0099
# Epoch 4/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 20s 73ms/step - loss: 0.0258 - val_loss: 0.0064
# Epoch 5/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 11s 80ms/step - loss: 0.0211 - val_loss: 0.0078
# Epoch 6/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - loss: 0.0215 - val_loss: 0.0049
# Epoch 7/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - loss: 0.0203 - val_loss: 0.0052
# Epoch 8/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 20s 77ms/step - loss: 0.0191 - val_loss: 0.0048
# Epoch 9/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - loss: 0.0170 - val_loss: 0.0054
# Epoch 10/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0160 - val_loss: 0.0092
# Epoch 11/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 21s 80ms/step - loss: 0.0165 - val_loss: 0.0048
# Epoch 12/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - loss: 0.0164 - val_loss: 0.0088
# Epoch 13/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 20s 74ms/step - loss: 0.0155 - val_loss: 0.0046
# Epoch 14/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - loss: 0.0151 - val_loss: 0.0074
# Epoch 15/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0129 - val_loss: 0.0083
# Epoch 16/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 21s 80ms/step - loss: 0.0134 - val_loss: 0.0092
# Epoch 17/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - loss: 0.0142 - val_loss: 0.0080
# Epoch 18/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 0.0129 - val_loss: 0.0072
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Fold 3 best val_loss: 0.0046
# Epoch 1/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - loss: 0.1163 - val_loss: 0.0242
# Epoch 2/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - loss: 0.0499 - val_loss: 0.0199
# Epoch 3/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0339 - val_loss: 0.0255
# Epoch 4/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0269 - val_loss: 0.0261
# Epoch 5/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0231 - val_loss: 0.0195
# Epoch 6/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0212 - val_loss: 0.0293
# Epoch 7/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - loss: 0.0195 - val_loss: 0.0177
# Epoch 8/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - loss: 0.0161 - val_loss: 0.0253
# Epoch 9/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - loss: 0.0167 - val_loss: 0.0192
# Epoch 10/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0180 - val_loss: 0.0265
# Epoch 11/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - loss: 0.0150 - val_loss: 0.0211
# Epoch 12/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0150 - val_loss: 0.0187
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Fold 4 best val_loss: 0.0177
# Epoch 1/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - loss: 0.1231 - val_loss: 0.0311
# Epoch 2/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - loss: 0.0503 - val_loss: 0.0349
# Epoch 3/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - loss: 0.0333 - val_loss: 0.0407
# Epoch 4/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - loss: 0.0254 - val_loss: 0.0228
# Epoch 5/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0244 - val_loss: 0.0202
# Epoch 6/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - loss: 0.0208 - val_loss: 0.0260
# Epoch 7/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 21s 79ms/step - loss: 0.0199 - val_loss: 0.0239
# Epoch 8/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0202 - val_loss: 0.0167
# Epoch 9/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - loss: 0.0185 - val_loss: 0.0231
# Epoch 10/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - loss: 0.0167 - val_loss: 0.0237
# Epoch 11/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 80ms/step - loss: 0.0171 - val_loss: 0.0257
# Epoch 12/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - loss: 0.0162 - val_loss: 0.0153
# Epoch 13/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 0.0150 - val_loss: 0.0117
# Epoch 14/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 21s 80ms/step - loss: 0.0152 - val_loss: 0.0165
# Epoch 15/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 19s 72ms/step - loss: 0.0141 - val_loss: 0.0169
# Epoch 16/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 11s 80ms/step - loss: 0.0149 - val_loss: 0.0246
# Epoch 17/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 21s 81ms/step - loss: 0.0137 - val_loss: 0.0125
# Epoch 18/20
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - loss: 0.0140 - val_loss: 0.0172
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Fold 5 best val_loss: 0.0117
#
# Overall best val_loss: 0.0046

# %%
mean_loss = np.mean(val_losses)
std_loss  = np.std(val_losses)
print(f"CV Mean val_loss: {mean_loss:.4f} ± {std_loss:.4f}")
# Out:
# CV Mean val_loss: 0.0117 ± 0.0063

# %%
import matplotlib.pyplot as plt
import numpy as np

y_pred_scaled = best_model.predict(X_test)

# 1) Обратное преобразование теста
original_test = scaler.inverse_transform(test_scaled)  # (n_test_samples, n_features)

# 2) Последние 20 дат из исходного датафрейма
dates = result_df.index[-len(test_scaled):]            # индексы теста
last_20_dates = dates[-20:]                            # последние 20 дат

# 3) Прогноз последнего окна
pred_last_14_scaled = y_pred_scaled[-1]                # (14,)
zeros_after = np.zeros((14, test_scaled.shape[1] - 1)) # если целевой признак — первая колонка
to_inverse = np.hstack([pred_last_14_scaled.reshape(-1, 1), zeros_after])
y_pred_last14_real = scaler.inverse_transform(to_inverse)[:, 0]

# 4) Реальные значения за последние 20 дней
last_20_real = original_test[-20:, 0]

# 5) Построение графика
plt.figure(figsize=(12, 6))
plt.plot(last_20_dates, last_20_real, marker='o', label='Actual (last 20 days)')
plt.plot(last_20_dates[-14:], y_pred_last14_real, marker='o', linestyle='--', label='Predicted (14-day horizon)')
plt.axvspan(last_20_dates[-14], last_20_dates[-1], color='gray', alpha=0.2)

plt.xlabel('Date')
plt.ylabel('Portfolio value')
plt.title('Actual vs. Predicted for Last 20 Days (14-day Forecast)')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score

# Предполагается, что следующие массивы уже есть в окружении:
# actual_last_14_real  — реальные значения (shape = (14,))
# y_pred_last14_real   — прогнозы модели (shape = (14,))
# last_20_dates        — pd.DatetimeIndex длиной ≥ 14, содержащий даты для этих значений

# 1) Рассчёт метрик
actual_last_14_real = original_test[-14:, 0]

mae  = mean_absolute_error(actual_last_14_real, y_pred_last14_real)
mape = mean_absolute_percentage_error(actual_last_14_real, y_pred_last14_real)
rmse = np.sqrt(mean_squared_error(actual_last_14_real, y_pred_last14_real))
r2 = r2_score(actual_last_14_real, y_pred_last14_real)

print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.2%}")
print(f"RMSE: {rmse:.4f}")

# 2) Таблица сравнения факта и прогноза
df_compare = pd.DataFrame({
    "Date":      last_20_dates[-14:],
    "Actual":    actual_last_14_real,
    "Predicted": y_pred_last14_real
})

from IPython.display import display
display(df_compare)

# При необходимости вывести таблицу в стандартном виде:
# print(df_compare.to_string(index=False))
# Out:
# MAE:  95.7184
# MAPE: 11.04%
# RMSE: 105.2226
#          Date      Actual    Predicted
# 0  2024-12-18  817.957797   989.373625
# 1  2024-12-19  805.393029   941.743758
# 2  2024-12-20  810.449585   907.441238
# 3  2024-12-21  924.738692   829.989003
# 4  2024-12-22  924.738692   796.076203
# 5  2024-12-23  811.563426   846.250195
# 6  2024-12-24  813.977743   883.835904
# 7  2024-12-25  924.738692   826.421494
# 8  2024-12-26  924.738692   809.844588
# 9  2024-12-27  822.136969   911.195643
# 10 2024-12-28  924.738692   763.646426
# 11 2024-12-29  924.738692  1007.291284
# 12 2024-12-30  820.719522   868.127210
# 13 2024-12-31  831.305501   845.325555
